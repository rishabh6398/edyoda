# %%
class main:
    def welcome(self):
        print(' ----------------------------------------')
        print('          [-: BookMyTicket :-]           ')
        print('-----------------------------------------')
        print("HELLO!! Welcome to movie ticket booking: ")
        print('Are you USER or ADMIN')
        print('For USER press-1')
        print('For ADMIN press-2')
        choice=int(input('Enter choice of number:'))
        if choice==1:
            self.city()
        elif choice==2:
            self.statistics()
        else:
            print('Choose either 1 or 2')
            self.welcome()
    def city(self):
        print("Please, select your city:")
        print("1:Mumbai")
        print("2:Delhi ")
        print("3:Bengaluru ")
        print("4:Hyderabad")
        print("5:Kolkata ")
        print("6:Ahmedabad")
        print("7:Chandigarh")
        print("8:Chennai ")
        print("9:Pune")
        print("10:Kochi")
        city_dict={1:'Mumbai',2:'Delhi',3:'Bengaluru',4:'Hyderabad',5:'Kolkata',6:'Ahmedabad',7:'Chandigarh',8:'Chennai',9:'Pune',10:'Kochi'}
        place = int(input("Choose your City: "))
        self.place=place
        print("You are from "+city_dict[self.place])
    
        if self.place == 1:
            self.movie_name()
        elif self.place == 2:
            self.movie_name()
        elif self.place == 3:
            self.movie_name()
        elif self.place == 4:
            self.movie_name()           
        elif self.place == 5:
            self.movie_name()
        elif self.place == 6:
            self.movie_name()
        elif self.place == 7:
            self.movie_name()
        elif self.place == 8:
            self.movie_name()
        elif self.place == 9:
            self.movie_name()
        elif self.place == 10:
            self.movie_name()
        else:
            print("Please select from the above options only")
            self.city()
    
    def movie_name(self):
        city_dict={1:"Mumbai", 2:'Hyderabad' , 3:'Delhi', 4:'Chennai', 5:'Kolkata', 6:'Vishakhapatnam',7:'Pune',8:'Gurgaon',9:'Noida',10:'Indore',11:'Gwalior',12:'Mysore',13:'Jaipur', 14:'Allahabad', 15:'Ahemdabad' }
        print("which movie do you want to watch?")
        print("1: uppena ")        
        print("2: master ")
        print("3: love aaj kal 2")
        print("4: dabang 4")
        print("5: Lost in space ")
        print("6: Witcher ")
        print("7: xyz")
        print("8: Back")
        movie = int(input("choose your movie: "))
        self.movie=movie
        if self.movie in range(1,8):
            self.purpose()
        else:
            self.movie_name()
    def purpose(self):
        print( 'For the selected movie, proceed and select one of the given options:')
        print('1: Show the seats')
        print('2: Buy a ticket')
        print('3: Statistics')
        print('4: Show booked ticket user info')
        select_option=int(input('type your response:'))
        if select_option==1:
            self.show_the_seat()
        elif select_option==2:
            self.buy_the_ticket()
        elif select_option==3:
            self.statistics()
        elif select_option==4:
            self.User_info()
        else:
            print('Choose only the above options.')
            self.purpose()
    global total_income
    total_income=0
    def show_the_seat(self):
        
        number_of_rows= int(input('The no. of rows:'))
        self.number_of_rows=number_of_rows
        number_of_columns=int(input('The no. of columns: '))
        self.number_of_columns=number_of_columns
        print('  ', end='')
        for k in range(1 , number_of_columns+1):
            self.k=k
    
            print(k , end=' ')
        print(end='\n')   
        cinema = []
        if self.number_of_columns<11:
            for j in range(1,number_of_rows+1):
                column = []
                column.append(j)
                for i in range(1,self.number_of_columns+1):
        
                    column.append('S')
                cinema.append(column)
            for column in cinema:
                for item in column:
                    self.item=item
                    print(item, end = " ")
                print()
        elif self.number_of_columns>10:
            for j in range(1,number_of_rows+1):
                column = []
                column.append(j)
                for i in range(1,10):
                    column.append('S')
                for i in range(10,self.number_of_columns+1):
                    column.append('S ')
                
                cinema.append(column)
            for column in cinema:
                for item in column:
                    self.item=item
                    print(item, end = " ")
                print()
        print('S is for vaccant seat and B is for booked ')
        print('Do you want to \n 1:book the ticket \n  Press any key:Go back')
        answer=int(input())
        if answer==1:
            self.buy_the_ticket()
        else:
            self.purpose()
    global dictionary_of_users
    dictionary_of_users={}
    global user 
    user=0    
    def buy_the_ticket(self):
        
        global user
        global dictionary_of_users 
        ticket_number=0
        
        row=int(input('Which row no. you wish to book the ticket?:'))
        self.row=row
        column=int(input('Which column no. you wish to book the ticket?:'))
        self.column=column
        if row<self.number_of_rows+1 and column<self.number_of_columns+1:
            if self.number_of_rows*self.number_of_columns<60:
                price=int(10)
                self.price=price
                print('The price of ticket is: $10')
                    
            elif self.number_of_rows*self.number_of_columns>60:
                if self.number_of_rows/2<row:
                    price=int(8)
                    self.price=price
                    print('The price of ticket is: $8')
                        
                else:
                    price=int(10)
                    self.price=price
                    print('The price of ticket is: $10')
                       
        else:
            print('The choose row/column is out of range')
            self.buy_the_ticket()
                
        print('Do you want to book the ticket?')
        print('1: Yes')
        print('2: Select another seat')
        answer=int(input('Press 1 or 2:'))
        if answer==1:
            user+=1
            user_dict={}
            print('Please provide the following information:')
            user_dict['User']='user'+str(user) 
            user_dict['Name']=input('Name:')
            user_dict['Age']=input('Age:')
            user_dict['Gender']=input('Gender:')
            user_dict['Phone_number']=input('Phone no.:')
            key=str(row)+','+str(column)
            dictionary_of_users[key]=user_dict
            self.payment()
        elif answer==2:
            self.buy_the_ticket()
        print(dictionary_of_users)
    def payment(self):
        global total_income
        print('You are paying to book ticket of row no.', self.row, 'and column no.', self.column, 'for the price $' + str(self.price) )
        print('The following payment options are available:')
        print('1: credit card')
        print('2: debit card')
        print('3: UPI')
        print('4: Back to seat selection')
        payment_opt=int(input('Enter the no.:'))
        if payment_opt==1 or payment_opt==2 or payment_opt==3:
            card_number=int(input('Enter the card no.:'))
            print('Payment is success full for row no.', self.row, 'and column no.', self.column, 'for the price $' + str(self.price))
            total_income=total_income+self.price
            
    def statistics(self):
        print('ALERT!! Access only to admin.')
        password=input('enter admin password:')
        if password=='admin001':
            print('Welcome admin')
            self.statistics1()
            
        else:
            print("wrong password. Access denied")
            self.statistics()
    def statistics1(self):
        print('The no. of purchased tickets are:', user)
        
        print(total_income)
        
    def User_info(self):
        print('ALERT!! Access only to admin.')
        password=input('enter admin password:')
        if password=='admin001':
            print('Welcome admin')
        else:
            print("wrong password. Access denied")
            self.User_info()
x=main()
x.welcome()
# Out:
#  ----------------------------------------
#           [-: BookMyTicket :-]
# -----------------------------------------
# HELLO!! Welcome to movie ticket booking:
# Are you USER or ADMIN
# For USER press-1
# For ADMIN press-2
# Enter choice of number:1
# Please, select your city:
# 1:Mumbai
# 2:Delhi
# 3:Bengaluru
# 4:Hyderabad
# 5:Kolkata
# 6:Ahmedabad
# 7:Chandigarh
# 8:Chennai
# 9:Pune
# 10:Kochi
# Choose your City: 1
# You are from Mumbai
# which movie do you want to watch?
# 1: uppena
# 2: master
# 3: love aaj kal 2
# 4: dabang 4
# 5: Lost in space
# 6: Witcher
# 7: xyz
# 8: Back
# choose your movie: 2
# For the selected movie, proceed and select one of the given options:
# 1: Show the seats
# 2: Buy a ticket
# 3: Statistics
# 4: Show booked ticket user info
# type your response:1
# The no. of rows:4
# The no. of columns: 5
#   1 2 3 4 5
# 1 S S S S S
# 2 S S S S S
# 3 S S S S S
# 4 S S S S S
# S is for vaccant seat and B is for booked
# Do you want to
#  1:book the ticket
#   Press any key:Go back
# 1
# Which row no. you wish to book the ticket?:3
# Which column no. you wish to book the ticket?:8
# The choose row/column is out of range
